# %% [markdown]
# <a href="https://colab.research.google.com/github/SharanyaReddy27/BlogApp/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lock , ilock
#drop methos
#isnull
#df.info
#iqr
#how to convert categorical data into numerical data
#sql operations using pandas

# %%
import pandas as pd

df = pd.read_csv("netflix_data.csv")

df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.drop(["listed_in","description"], axis=1, inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  release_year  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson          2020
# 1         s2  TV Show          Blood & Water              NaN          2021
# 2         s3  TV Show              Ganglands  Julien Leclercq          2021
# 3         s4  TV Show  Jailbirds New Orleans              NaN          2021
# 4         s5  TV Show           Kota Factory              NaN          2021
# ...      ...      ...                    ...              ...           ...
# 8802   s8803    Movie                 Zodiac    David Fincher          2007
# 8803   s8804  TV Show            Zombie Dumb              NaN          2018
# 8804   s8805    Movie             Zombieland  Ruben Fleischer          2009
# 8805   s8806    Movie                   Zoom     Peter Hewitt          2006
# 8806   s8807    Movie                 Zubaan      Mozez Singh          2015
#
#      rating   duration
# 0     PG-13     90 min
# ...

# %%
print(df.head())
print(df.tail())
print(df.shape)
print(df.columns)
print(df.index)
print(df.info())
# Out:
#   show_id     type                  title         director  release_year  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson          2020
# 1      s2  TV Show          Blood & Water              NaN          2021
# 2      s3  TV Show              Ganglands  Julien Leclercq          2021
# 3      s4  TV Show  Jailbirds New Orleans              NaN          2021
# 4      s5  TV Show           Kota Factory              NaN          2021
#
#   rating   duration
# 0  PG-13     90 min
# 1  TV-MA  2 Seasons
# 2  TV-MA   1 Season
# 3  TV-MA   1 Season
# 4  TV-MA  2 Seasons
#      show_id     type        title         director  release_year rating  \
# 8802   s8803    Movie       Zodiac    David Fincher          2007      R
# 8803   s8804  TV Show  Zombie Dumb              NaN          2018  TV-Y7
# 8804   s8805    Movie   Zombieland  Ruben Fleischer          2009      R
# 8805   s8806    Movie         Zoom     Peter Hewitt          2006     PG
# ...

# %%
print(df.isnull())
# Out:
#       show_id   type  title  director  release_year  rating  duration
# 0       False  False  False     False         False   False     False
# 1       False  False  False      True         False   False     False
# 2       False  False  False     False         False   False     False
# 3       False  False  False      True         False   False     False
# 4       False  False  False      True         False   False     False
# ...       ...    ...    ...       ...           ...     ...       ...
# 8802    False  False  False     False         False   False     False
# 8803    False  False  False      True         False   False     False
# 8804    False  False  False     False         False   False     False
# 8805    False  False  False     False         False   False     False
# 8806    False  False  False     False         False   False     False
#
# [8807 rows x 7 columns]

# %%
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# release_year       0
# rating             4
# duration           3
# dtype: int64

# %%
print(df.isnull().any())
# Out:
# show_id         False
# type            False
# title           False
# director         True
# release_year    False
# rating           True
# duration         True
# dtype: bool

# %%
df.dropna(inplace=True)
df
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  release_year rating  duration
# 0                   Kirsten Johnson          2020  PG-13    90 min
# 2                   Julien Leclercq          2021  TV-MA  1 Season
# 5                     Mike Flanagan          2021  TV-MA  1 Season
# ...

# %%
df = pd.read_csv("netflix_data.csv")
print(df["duration"].head(20))
print(df["duration"].dtype)
df["duration"] = df["duration"].astype(str).str.extract(r'(\d+\.?\d*)')[0]
df["duration"] = pd.to_numeric(df["duration"], errors="coerce")
df["duration"] = df["duration"].fillna(df["duration"].mean())
# Out:
# 0        90 min
# 1     2 Seasons
# 2      1 Season
# 3      1 Season
# 4     2 Seasons
# 5      1 Season
# 6        91 min
# 7       125 min
# 8     9 Seasons
# 9       104 min
# 10     1 Season
# 11     1 Season
# 12      127 min
# 13       91 min
# 14     1 Season
# 15    4 Seasons
# 16       67 min
# 17    2 Seasons
# 18       94 min
# 19     1 Season
# Name: duration, dtype: object
# object

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# release_year       0
# rating             4
# duration           0
# dtype: int64

# %%
df.drop(["cast","country","date_added","listed_in","description"], axis=1, inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  release_year  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson          2020
# 1         s2  TV Show          Blood & Water              NaN          2021
# 2         s3  TV Show              Ganglands  Julien Leclercq          2021
# 3         s4  TV Show  Jailbirds New Orleans              NaN          2021
# 4         s5  TV Show           Kota Factory              NaN          2021
# ...      ...      ...                    ...              ...           ...
# 8802   s8803    Movie                 Zodiac    David Fincher          2007
# 8803   s8804  TV Show            Zombie Dumb              NaN          2018
# 8804   s8805    Movie             Zombieland  Ruben Fleischer          2009
# 8805   s8806    Movie                   Zoom     Peter Hewitt          2006
# 8806   s8807    Movie                 Zubaan      Mozez Singh          2015
#
#      rating  duration
# 0     PG-13      90.0
# ...

# %%
df["rating"] = df["rating"].fillna(df["rating"].mode()[0])

# %%
df.fillna(method="ffill", inplace=True)
# Out:
# /tmp/ipykernel_476/173857299.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)

# %%
df.fillna(method="bfill", inplace=True)
# Out:
# /tmp/ipykernel_476/1916524838.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   release_year  8807 non-null   int64
#  5   rating        8807 non-null   object
#  6   duration      8807 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 481.8+ KB

# %%
Q1 = df["release_year"].quantile(0.25)
Q3 = df["release_year"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Lower limit:", lower)
print("Upper limit:", upper)
# Out:
# Lower limit: 2004.0
# Upper limit: 2028.0

# %%
outliers = df[
    (df["release_year"] < lower) |
    (df["release_year"] > upper)
]

print(outliers)
# Out:
#      show_id   type              title          director  release_year rating  \
# 7         s8  Movie            Sankofa      Haile Gerima          1993  TV-MA
# 22       s23  Movie    Avvai Shanmughi    K.S. Ravikumar          1996  TV-PG
# 24       s25  Movie              Jeans        S. Shankar          1998  TV-14
# 26       s27  Movie     Minsara Kanavu       Rajiv Menon          1997  TV-PG
# 41       s42  Movie               Jaws  Steven Spielberg          1975     PG
# ...      ...    ...                ...               ...           ...    ...
# 8764   s8765  Movie         Wyatt Earp   Lawrence Kasdan          1994  PG-13
# 8766   s8767  Movie                XXx         Rob Cohen          2002  PG-13
# 8768   s8769  Movie  Y Tu Mamá También    Alfonso Cuarón          2001      R
# 8770   s8771  Movie            Yaadein      Subhash Ghai          2001  TV-14
# 8792   s8793  Movie        Young Tiger            Mu Chu          1973     NR
#
#       duration
# 7        125.0
# ...

# %%
df = df[
    (df["release_year"] >= lower) &
    (df["release_year"] <= upper)
]

# %%
df
# Out:
#      show_id     type                  title         director  release_year  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson          2020
# 1         s2  TV Show          Blood & Water  Kirsten Johnson          2021
# 2         s3  TV Show              Ganglands  Julien Leclercq          2021
# 3         s4  TV Show  Jailbirds New Orleans  Julien Leclercq          2021
# 4         s5  TV Show           Kota Factory  Julien Leclercq          2021
# ...      ...      ...                    ...              ...           ...
# 8802   s8803    Movie                 Zodiac    David Fincher          2007
# 8803   s8804  TV Show            Zombie Dumb    David Fincher          2018
# 8804   s8805    Movie             Zombieland  Ruben Fleischer          2009
# 8805   s8806    Movie                   Zoom     Peter Hewitt          2006
# 8806   s8807    Movie                 Zubaan      Mozez Singh          2015
#
#      rating  duration
# 0     PG-13      90.0
# ...

# %%
df.loc[2]
# Out:
# show_id                      s3
# type                    TV Show
# title                 Ganglands
# director        Julien Leclercq
# release_year               2021
# rating                    TV-MA
# duration                    1.0
# Name: 2, dtype: object

# %%
df.loc[0:4]
# Out:
#   show_id     type                  title         director  release_year  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson          2020
# 1      s2  TV Show          Blood & Water  Kirsten Johnson          2021
# 2      s3  TV Show              Ganglands  Julien Leclercq          2021
# 3      s4  TV Show  Jailbirds New Orleans  Julien Leclercq          2021
# 4      s5  TV Show           Kota Factory  Julien Leclercq          2021
#
#   rating  duration
# 0  PG-13      90.0
# 1  TV-MA       2.0
# 2  TV-MA       1.0
# 3  TV-MA       1.0
# 4  TV-MA       2.0

# %%
df.loc[:, ["show_id", "title"]]
# Out:
#      show_id                  title
# 0         s1   Dick Johnson Is Dead
# 1         s2          Blood & Water
# 2         s3              Ganglands
# 3         s4  Jailbirds New Orleans
# 4         s5           Kota Factory
# ...      ...                    ...
# 8802   s8803                 Zodiac
# 8803   s8804            Zombie Dumb
# 8804   s8805             Zombieland
# 8805   s8806                   Zoom
# 8806   s8807                 Zubaan
#
# [8088 rows x 2 columns]

# %%
df.loc[df["duration"] > 60.0]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# 13       s14  Movie  Confessions of an Invisible Girl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  release_year rating  duration
# 0                   Kirsten Johnson          2020  PG-13      90.0
# 6     Robert Cullen, José Luis Ucha          2021     PG      91.0
# 9                    Theodore Melfi          2021  PG-13     104.0
# ...

# %%
df.loc[(df["release_year"] > 2020) & (df["duration"] > 120)]
# Out:
#      show_id   type                                       title  \
# 12       s13  Movie                                Je Suis Karl
# 79       s80  Movie                     Tughlaq Durbar (Telugu)
# 190     s191  Movie                                  Thimmarusu
# 214     s215  Movie                 SAS: Rise of the Black Swan
# 236     s237  Movie                                     Boomika
# 237     s238  Movie                             Boomika (Hindi)
# 238     s239  Movie                         Boomika (Malayalam)
# 239     s240  Movie                            Boomika (Telugu)
# 372     s373  Movie              Rurouni Kenshin: The Beginning
# 387     s388  Movie                                        Mimi
# 396     s397  Movie                               Blood Red Sky
# 500     s501  Movie                   Major Grom: Plague Doctor
# 551     s552  Movie                             Haseen Dillruba
# 683     s684  Movie                                    A Family
# ...

# %%
df.iloc[0]
# Out:
# show_id                           s1
# type                           Movie
# title           Dick Johnson Is Dead
# director             Kirsten Johnson
# release_year                    2020
# rating                         PG-13
# duration                        90.0
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#   show_id     type                  title         director  release_year  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson          2020
# 1      s2  TV Show          Blood & Water  Kirsten Johnson          2021
# 2      s3  TV Show              Ganglands  Julien Leclercq          2021
# 3      s4  TV Show  Jailbirds New Orleans  Julien Leclercq          2021
# 4      s5  TV Show           Kota Factory  Julien Leclercq          2021
#
#   rating  duration
# 0  PG-13      90.0
# 1  TV-MA       2.0
# 2  TV-MA       1.0
# 3  TV-MA       1.0
# 4  TV-MA       2.0

# %%
df.iloc[0, 0]
# Out:
# 's1'

# %%
df.iloc[0:5, 0:3]
# Out:
#   show_id     type                  title
# 0      s1    Movie   Dick Johnson Is Dead
# 1      s2  TV Show          Blood & Water
# 2      s3  TV Show              Ganglands
# 3      s4  TV Show  Jailbirds New Orleans
# 4      s5  TV Show           Kota Factory

# %%
df = pd.read_csv("netflix_data.csv")
df.drop(["cast","country","date_added","listed_in","description"], axis=1, inplace=True)
df["type"] = df["type"].map({
    "Movie": 1,
    "TV Show": 0
})
df
# Out:
#      show_id  type                  title         director  release_year  \
# 0         s1     1   Dick Johnson Is Dead  Kirsten Johnson          2020
# 1         s2     0          Blood & Water              NaN          2021
# 2         s3     0              Ganglands  Julien Leclercq          2021
# 3         s4     0  Jailbirds New Orleans              NaN          2021
# 4         s5     0           Kota Factory              NaN          2021
# ...      ...   ...                    ...              ...           ...
# 8802   s8803     1                 Zodiac    David Fincher          2007
# 8803   s8804     0            Zombie Dumb              NaN          2018
# 8804   s8805     1             Zombieland  Ruben Fleischer          2009
# 8805   s8806     1                   Zoom     Peter Hewitt          2006
# 8806   s8807     1                 Zubaan      Mozez Singh          2015
#
#      rating   duration
# 0     PG-13     90 min
# 1     TV-MA  2 Seasons
# ...
