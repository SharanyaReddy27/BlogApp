# %% [markdown]
# <a href="https://colab.research.google.com/github/SharanyaReddy27/BlogApp/blob/master/week(3%2C4%2C5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
l1 = [71,0,1,2,3]
print(pd.Series(l1))
# Out:
# 0    71
# 1     0
# 2     1
# 3     2
# 4     3
# dtype: int64

# %%
import numpy as np
arr1 = np.array([71,10,20,30,40])
print(pd.Series(arr1))
# Out:
# 0    71
# 1    10
# 2    20
# 3    30
# 4    40
# dtype: int64

# %%
d1 = {
    'x': 71,
    'y': 72,
    'z': 73
}
print(pd.Series(d1))
# Out:
# x    71
# y    72
# z    73
# dtype: int64

# %%
d2 = {
    'Name' : ['shar','sudeep','vedha'],
    'Age' : [18,19,20]
}
df2 = pd.DataFrame(d2)
print(df2)
# Out:
#      Name  Age
# 0    shar   18
# 1  sudeep   19
# 2   vedha   20

# %%
l2 = [
    {'Name': 'shar', 'Age': 18},
    {'Name': 'sara', 'Age': 19},
    {'Name': 'sudep', 'Age': 19},
    {'Name':'vedh','Age':20}
]
print(pd.DataFrame(l2))
# Out:
#     Name  Age
# 0   shar   18
# 1   sara   19
# 2  sudep   19
# 3   vedh   20

# %%
l3 = [
    ['shar',18],
    ['sara',19],
    ['sudep',19],
    ['vedh',20]
]
print(pd.DataFrame(l3,columns=['Name','Age']))
# Out:
#     Name  Age
# 0   shar   18
# 1   sara   19
# 2  sudep   19
# 3   vedh   20

# %%
arr2= np.array([
    ['shar',18],
    ['sara',19],
    ['sudep',19],
    ['vedh',20]
])
print(pd.DataFrame(arr2,columns=['Name','Age']))
# Out:
#     Name Age
# 0   shar  18
# 1   sara  19
# 2  sudep  19
# 3   vedh  20

# %%
#Import any CSV file to Pandas Data Frame and perform the following:
import pandas as pd
df = pd.read_csv("Employers_data.csv")
print(df.head())
# Out:
#    Employee_ID            Name  Age  Gender   Department  Job_Title  \
# 0            1    Merle Ingram   24  Female  Engineering   Engineer
# 1            2      John Mayes   56    Male        Sales  Executive
# 2            3    Carlos Wille   21    Male  Engineering     Intern
# 3            4  Michael Bryant   30    Male      Finance    Analyst
# 4            5   Paula Douglas   25  Female           HR    Analyst
#
#    Experience_Years Education_Level  Location  Salary
# 0                 1          Master    Austin   90000
# 1                33          Master   Seattle  195000
# 2                 1        Bachelor  New York   35000
# 3                 9        Bachelor  New York   75000
# 4                 2          Master   Seattle   70000

# %%
df1 = df.drop(columns=['Gender','Experience_Years','Education_Level','Location'])
print(df1.head())
# Out:
#    Employee_ID            Name  Age   Department  Job_Title  Salary
# 0            1    Merle Ingram   24  Engineering   Engineer   90000
# 1            2      John Mayes   56        Sales  Executive  195000
# 2            3    Carlos Wille   21  Engineering     Intern   35000
# 3            4  Michael Bryant   30      Finance    Analyst   75000
# 4            5   Paula Douglas   25           HR    Analyst   70000

# %%
print(df1.head(10))
# Out:
#    Employee_ID               Name  Age   Department  Job_Title  Salary
# 0            1       Merle Ingram   24  Engineering   Engineer   90000
# 1            2         John Mayes   56        Sales  Executive  195000
# 2            3       Carlos Wille   21  Engineering     Intern   35000
# 3            4     Michael Bryant   30      Finance    Analyst   75000
# 4            5      Paula Douglas   25           HR    Analyst   70000
# 5            6     Michael Irving   35      Finance    Manager  125000
# 6            7  Marcelle Campbell   23    Marketing    Analyst   60000
# 7            8        Glenda Leal   47    Marketing    Manager  145000
# 8            9    Walter Williams   43    Marketing    Manager  135000
# 9           10     Vanessa Songer   23    Marketing    Analyst   70000

# %%
print(df1.tail(10))
# Out:
#       Employee_ID             Name  Age   Department  Job_Title  Salary
# 9990         9991     Sally Hudson   46      Finance    Manager  150000
# 9991         9992  Amanda Pariente   38  Engineering    Manager  125000
# 9992         9993     Corey Medina   27      Finance    Analyst   70000
# 9993         9994       Pedro Caul   51      Finance  Executive  200000
# 9994         9995       Laura Ross   31      Product   Engineer   95000
# 9995         9996    Thomas Rossin   51        Sales  Executive  185000
# 9996         9997    Christie King   36        Sales  Executive  165000
# 9997         9998    Alfred Keller   57        Sales  Executive  200000
# 9998         9999   Margaret Gomez   37  Engineering    Manager  135000
# 9999        10000    Joan Sorensen   25        Sales    Analyst   70000

# %%
print(df.shape)
# Out:
# (10000, 10)

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
print(df.columns)
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Experience_Years', 'Education_Level', 'Location', 'Salary'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Employee_ID          int64
# Name                object
# Age                  int64
# Gender              object
# Department          object
# Job_Title           object
# Experience_Years     int64
# Education_Level     object
# Location            object
# Salary               int64
# dtype: object

# %%
print(df1[df1['Salary']>200000])
# Out:
#       Employee_ID                 Name  Age Department  Job_Title  Salary
# 14             15         Carolyn Bell   59         HR  Executive  205000
# 110           111          Ashley Lane   60         HR  Executive  205000
# 231           232          Albert Ness   58    Finance  Executive  210000
# 234           235  Roosevelt Leonhardt   57    Finance  Executive  205000
# 295           296     Shannon Kujawski   60    Finance  Executive  205000
# ...           ...                  ...  ...        ...        ...     ...
# 9555         9556          Jane Reilly   58      Sales  Executive  205000
# 9693         9694          Lamar Borel   59    Finance  Executive  205000
# 9700         9701        Fanny Slayton   60         HR  Executive  210000
# 9825         9826       Megan Thompson   59    Finance  Executive  205000
# 9966         9967       Louise Baldwin   60      Sales  Executive  205000
#
# [173 rows x 6 columns]

# %%
print(df1[['Name','Age','Department']])
# Out:
#                 Name  Age   Department
# 0       Merle Ingram   24  Engineering
# 1         John Mayes   56        Sales
# 2       Carlos Wille   21  Engineering
# 3     Michael Bryant   30      Finance
# 4      Paula Douglas   25           HR
# ...              ...  ...          ...
# 9995   Thomas Rossin   51        Sales
# 9996   Christie King   36        Sales
# 9997   Alfred Keller   57        Sales
# 9998  Margaret Gomez   37  Engineering
# 9999   Joan Sorensen   25        Sales
#
# [10000 rows x 3 columns]

# %%
df3 = df.drop("Location", axis=1)
print(df3.head())
# Out:
#    Employee_ID            Name  Age  Gender   Department  Job_Title  \
# 0            1    Merle Ingram   24  Female  Engineering   Engineer
# 1            2      John Mayes   56    Male        Sales  Executive
# 2            3    Carlos Wille   21    Male  Engineering     Intern
# 3            4  Michael Bryant   30    Male      Finance    Analyst
# 4            5   Paula Douglas   25  Female           HR    Analyst
#
#    Experience_Years Education_Level  Salary
# 0                 1          Master   90000
# 1                33          Master  195000
# 2                 1        Bachelor   35000
# 3                 9        Bachelor   75000
# 4                 2          Master   70000

# %%
# Out:
#    Employee_ID            Name  Age  Gender   Department  Job_Title  \
# 0            1    Merle Ingram   24  Female  Engineering   Engineer
# 1            2      John Mayes   56    Male        Sales  Executive
# 2            3    Carlos Wille   21    Male  Engineering     Intern
# 3            4  Michael Bryant   30    Male      Finance    Analyst
# 4            5   Paula Douglas   25  Female           HR    Analyst
#
#    Experience_Years Education_Level  Salary
# 0                 1          Master   90000
# 1                33          Master  195000
# 2                 1        Bachelor   35000
# 3                 9        Bachelor   75000
# 4                 2          Master   70000

# %%
df1 = df.drop(columns=['Gender','Experience_Years','Education_Level','Location'])
print(df1.head())
# Out:
#    Employee_ID            Name  Age   Department  Job_Title  Salary
# 0            1    Merle Ingram   24  Engineering   Engineer   90000
# 1            2      John Mayes   56        Sales  Executive  195000
# 2            3    Carlos Wille   21  Engineering     Intern   35000
# 3            4  Michael Bryant   30      Finance    Analyst   75000
# 4            5   Paula Douglas   25           HR    Analyst   70000

# %%
df4 = df1[df1['Age']>30]
print(df4)
# Out:
#       Employee_ID             Name  Age   Department  Job_Title  Salary
# 1               2       John Mayes   56        Sales  Executive  195000
# 5               6   Michael Irving   35      Finance    Manager  125000
# 7               8      Glenda Leal   47    Marketing    Manager  145000
# 8               9  Walter Williams   43    Marketing    Manager  135000
# 12             13     Lionel Elsea   48      Product    Manager  150000
# ...           ...              ...  ...          ...        ...     ...
# 9994         9995       Laura Ross   31      Product   Engineer   95000
# 9995         9996    Thomas Rossin   51        Sales  Executive  185000
# 9996         9997    Christie King   36        Sales  Executive  165000
# 9997         9998    Alfred Keller   57        Sales  Executive  200000
# 9998         9999   Margaret Gomez   37  Engineering    Manager  135000
#
# [5867 rows x 6 columns]

# %%
df1['Rank'] = df1['Salary'].rank()
print(df1)
# Out:
#       Employee_ID            Name  Age   Department  Job_Title  Salary    Rank
# 0               1    Merle Ingram   24  Engineering   Engineer   90000  3663.0
# 1               2      John Mayes   56        Sales  Executive  195000  9515.0
# 2               3    Carlos Wille   21  Engineering     Intern   35000   251.5
# 3               4  Michael Bryant   30      Finance    Analyst   75000  2806.0
# 4               5   Paula Douglas   25           HR    Analyst   70000  2084.5
# ...           ...             ...  ...          ...        ...     ...     ...
# 9995         9996   Thomas Rossin   51        Sales  Executive  185000  9101.5
# 9996         9997   Christie King   36        Sales  Executive  165000  8296.0
# 9997         9998   Alfred Keller   57        Sales  Executive  200000  9721.0
# 9998         9999  Margaret Gomez   37  Engineering    Manager  135000  6397.5
# 9999        10000   Joan Sorensen   25        Sales    Analyst   70000  2084.5
#
# ...

# %%
df1['Rank'] = df1['Salary'].rank(ascending=True)
print(df1)
# Out:
#       Employee_ID            Name  Age   Department  Job_Title  Salary    Rank
# 0               1    Merle Ingram   24  Engineering   Engineer   90000  3663.0
# 1               2      John Mayes   56        Sales  Executive  195000  9515.0
# 2               3    Carlos Wille   21  Engineering     Intern   35000   251.5
# 3               4  Michael Bryant   30      Finance    Analyst   75000  2806.0
# 4               5   Paula Douglas   25           HR    Analyst   70000  2084.5
# ...           ...             ...  ...          ...        ...     ...     ...
# 9995         9996   Thomas Rossin   51        Sales  Executive  185000  9101.5
# 9996         9997   Christie King   36        Sales  Executive  165000  8296.0
# 9997         9998   Alfred Keller   57        Sales  Executive  200000  9721.0
# 9998         9999  Margaret Gomez   37  Engineering    Manager  135000  6397.5
# 9999        10000   Joan Sorensen   25        Sales    Analyst   70000  2084.5
#
# ...

# %%
df5 = df1.drop(columns=['Job_Title'])
print(df5.head())
# Out:
#    Employee_ID            Name  Age   Department  Salary    Rank
# 0            1    Merle Ingram   24  Engineering   90000  3663.0
# 1            2      John Mayes   56        Sales  195000  9515.0
# 2            3    Carlos Wille   21  Engineering   35000   251.5
# 3            4  Michael Bryant   30      Finance   75000  2806.0
# 4            5   Paula Douglas   25           HR   70000  2084.5

# %%
print(df5.sort_values(by="Salary"))
# Out:
#       Employee_ID               Name  Age   Department  Salary    Rank
# 8536         8537          Sarah Fox   24  Engineering   25000     5.5
# 6237         6238  Michael Henderson   25  Engineering   25000     5.5
# 9630         9631       Olga Goodier   22  Engineering   25000     5.5
# 2420         2421     Melvin Destina   24  Engineering   25000     5.5
# 8496         8497          James Ray   22  Engineering   25000     5.5
# ...           ...                ...  ...          ...     ...     ...
# 1783         1784      Heather Himes   58      Finance  210000  9980.5
# 1772         1773         Kevin Best   58        Sales  210000  9980.5
# 3949         3950      Willis Holmes   59           HR  215000  9999.0
# 2132         2133        Mark Newman   59      Finance  215000  9999.0
# 9423         9424  Alexander Compton   59           HR  215000  9999.0
#
# [10000 rows x 6 columns]

# %%
print(df5.sort_values(by="Age", ascending=False))
# Out:
#       Employee_ID               Name  Age   Department  Salary    Rank
# 5416         5417        Linda Vigil   60        Sales  210000  9980.5
# 7750         7751        Somer Mayer   60        Sales  210000  9980.5
# 5473         5474       David Jumper   60      Finance  205000  9895.5
# 558           559         Tony Rosas   60        Sales  205000  9895.5
# 5294         5295        Brian Cross   60        Sales  200000  9721.0
# ...           ...                ...  ...          ...     ...     ...
# 6796         6797     Frank Browning   21  Engineering   35000   251.5
# 6806         6807       Sadie Grogan   21  Engineering   35000   251.5
# 9006         9007        Corey Grant   21  Engineering   35000   251.5
# 1916         1917          Lila West   21  Engineering   40000   470.0
# 6756         6757  Darlene Dominguez   21  Engineering   40000   470.0
#
# [10000 rows x 6 columns]

# %%
print(df5.describe())
# Out:
#        Employee_ID           Age         Salary          Rank
# count  10000.00000  10000.000000   10000.000000  10000.000000
# mean    5000.50000     35.455900  115381.500000   5000.500000
# std     2886.89568     10.000213   46066.139047   2884.026977
# min        1.00000     21.000000   25000.000000      5.500000
# 25%     2500.75000     27.000000   70000.000000   2084.500000
# 50%     5000.50000     34.000000  120000.000000   5099.000000
# 75%     7500.25000     43.000000  150000.000000   7672.500000
# max    10000.00000     60.000000  215000.000000   9999.000000

# %%
print(df5['Age'].min())
print(df5['Salary'].max())
print(df5['Rank'].mean())
print(df5['Age'].median())
print(df5['Age'].mode())
# Out:
# 21
# 215000
# 5000.5
# 34.0
# 0    30
# Name: Age, dtype: int64

# %%
print(df["Department"].value_counts())
# Out:
# Department
# Product        1724
# Engineering    1683
# Sales          1669
# Marketing      1669
# HR             1660
# Finance        1595
# Name: count, dtype: int64

# %%
print(df["Department"].unique())
# Out:
# ['Engineering' 'Sales' 'Finance' 'HR' 'Marketing' 'Product']

# %%
print(df["Department"].nunique())
# Out:
# 6

# %%
df5.rename(columns={"Salary": "Monthly_Salary"}, inplace=True)
print(df5.head())
# Out:
#    Employee_ID            Name  Age   Department  Monthly_Salary    Rank
# 0            1    Merle Ingram   24  Engineering           90000  3663.0
# 1            2      John Mayes   56        Sales          195000  9515.0
# 2            3    Carlos Wille   21  Engineering           35000   251.5
# 3            4  Michael Bryant   30      Finance           75000  2806.0
# 4            5   Paula Douglas   25           HR           70000  2084.5

# %%
df5.rename(columns={
    "Employee_ID": "Emp_ID",
    "Name": "Emp_Name",
    "Age": "Emp_Age",
    "Department": "Emp_Dept",
}, inplace=True)

print(df5.head())
# Out:
#    Emp_ID        Emp_Name  Emp_Age     Emp_Dept  Monthly_Salary    Rank
# 0       1    Merle Ingram       24  Engineering           90000  3663.0
# 1       2      John Mayes       56        Sales          195000  9515.0
# 2       3    Carlos Wille       21  Engineering           35000   251.5
# 3       4  Michael Bryant       30      Finance           75000  2806.0
# 4       5   Paula Douglas       25           HR           70000  2084.5
